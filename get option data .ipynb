# %%
from maticalgos.historical import historical

ma = historical('lakshyatiwari111@gmail.com')
ma.login("887874") ##Password as sent on email

# %%
import datetime

data = ma.get_data("nifty", datetime.date(2016,1,5))

#Data available only for nifty options from 2019 and banknifty options from 2018
#Date should be in datetime.date format
#Data would be in pandas DataFrame format
print('done')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [10], in <cell line: 3>()
#       1 import datetime
# ----> 3 data = ma.get_data("nifty", datetime.date(2016,1,5))
#       5 #Data available only for nifty options from 2019 and banknifty options from 2018
#       6 #Date should be in datetime.date format
#       7 #Data would be in pandas DataFrame format
#       8 print('done')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\maticalgos\historical.py:44, in historical.get_data(self, symbol, dat)
#      41 n = r.json()
#      43 if n['status'] == False:
# ---> 44     raise Exception(n['error'])
#      45 else:
#      46     df = pd.DataFrame.from_dict(n['data'][0])
#
# Exception: Unable to fetch data for 2016-01-05

# %%
data

# %%
start_date = datetime.date(2022, 5, 8)

if start_date.isoweekday()==6:
    start_date = start_date + timedelta(days=2)
else:
    start_date = start_date + timedelta(days=1)

start_date
# Out:
# datetime.date(2022, 5, 9)

# %%
date(2019,2,7) + timedelta(days=1)
# Out:
# datetime.date(2019, 2, 8)

# %%
data
# Out:
#           close        date      exp      high       low   oi      open  \
# 0        910.00  02/11/2019  14FEB19    910.00    910.00    0    910.00
# 1        888.50  02/11/2019  14FEB19    888.50    888.50   75    888.50
# 2        869.35  02/11/2019  14FEB19    869.35    869.35  150    869.35
# 3        882.90  02/11/2019  14FEB19    882.90    882.90  300    882.90
# 4        877.80  02/11/2019  14FEB19    877.80    877.80  600    877.80
# ...         ...         ...      ...       ...       ...  ...       ...
# 10072   10894.9  02/11/2019        0  10896.15   10893.8    0   10893.9
# 10073   10895.0  02/11/2019        0  10896.25   10894.1    0   10894.5
# 10074   10897.7  02/11/2019        0   10897.7   10894.6    0   10894.6
# 10075   10900.2  02/11/2019        0   10900.2  10896.75    0  10896.75
# 10076  10900.75  02/11/2019        0   10902.9   10900.0    0   10900.0
#
#         strike               symbol             ticker      time volume
# ...

# %%
a=pd.DataFrame()
pd.concat([a,data])
# Out:
#           close        date      exp      high       low   oi      open  \
# 0        910.00  02/11/2019  14FEB19    910.00    910.00    0    910.00
# 1        888.50  02/11/2019  14FEB19    888.50    888.50   75    888.50
# 2        869.35  02/11/2019  14FEB19    869.35    869.35  150    869.35
# 3        882.90  02/11/2019  14FEB19    882.90    882.90  300    882.90
# 4        877.80  02/11/2019  14FEB19    877.80    877.80  600    877.80
# ...         ...         ...      ...       ...       ...  ...       ...
# 10072   10894.9  02/11/2019        0  10896.15   10893.8    0   10893.9
# 10073   10895.0  02/11/2019        0  10896.25   10894.1    0   10894.5
# 10074   10897.7  02/11/2019        0   10897.7   10894.6    0   10894.6
# 10075   10900.2  02/11/2019        0   10900.2  10896.75    0  10896.75
# 10076  10900.75  02/11/2019        0   10902.9   10900.0    0   10900.0
#
#         strike               symbol             ticker      time volume
# ...

# %% [markdown]
# ## get data

# %%
from maticalgos.historical import historical
from datetime import timedelta,date
import pandas as pd

ma = historical('lakshyatiwari111@gmail.com')
ma.login("887874") ##Password as sent on email 

start_date = date(2022, 1, 28)
end_date = date(2022, 8, 30)
main_data = pd.DataFrame()

while True:
        
    if start_date.isoweekday()==6:
        start_date = start_date + timedelta(days=2)
        
    if start_date > end_date:
        break
    else:
        try:
            print('Date---->',start_date)
            data = ma.get_data("banknifty",start_date) #symbol(nifty/banknifty)
            main_data = pd.concat([main_data,data])
        except:
            print('date is not available--->',start_date)
            
        start_date = start_date + timedelta(days=1)
# Out:
# Date----> 2022-01-28
# Date----> 2022-01-31
# Date----> 2022-02-01
# Date----> 2022-02-02
# Date----> 2022-02-03
# Date----> 2022-02-04
# Date----> 2022-02-07
# Date----> 2022-02-08
# Date----> 2022-02-09
# Date----> 2022-02-10
# Date----> 2022-02-11
# Date----> 2022-02-14
# Date----> 2022-02-15
# Date----> 2022-02-16
# Date----> 2022-02-17
# Date----> 2022-02-18
# Date----> 2022-02-21
# Date----> 2022-02-22
# Date----> 2022-02-23
# Date----> 2022-02-24
# Date----> 2022-02-25
# Date----> 2022-02-28
# Date----> 2022-03-01
# date is not available---> 2022-03-01
# Date----> 2022-03-02
# Date----> 2022-03-03
# Date----> 2022-03-04
# Date----> 2022-03-07
# Date----> 2022-03-08
# Date----> 2022-03-09
# Date----> 2022-03-10
# Date----> 2022-03-11
# Date----> 2022-03-14
# Date----> 2022-03-15
# Date----> 2022-03-16
# Date----> 2022-03-17
# Date----> 2022-03-18
# date is not available---> 2022-03-18
# Date----> 2022-03-21
# Date----> 2022-03-22
# Date----> 2022-03-23
# Date----> 2022-03-24
# ...

# %%
main_data.reset_index(inplace=True)
main_data
# Out:
#          index     close        date      high       low      oi      open  \
# 0            0    8035.6  2022-01-28    8035.6    8035.6     0.0    8035.6
# 1            1    7977.6  2022-01-28    7977.6    7977.6     0.0    7977.6
# 2            2      4.55  2022-01-28      4.55      3.05    25.0      3.05
# 3            3       4.0  2022-01-28      4.55      3.85  3175.0      4.55
# 4            4       4.0  2022-01-28       4.0      3.95  3175.0      3.95
# ...        ...       ...         ...       ...       ...     ...       ...
# 7041817  47139  39587.65  2022-08-30   39597.9   39579.7     nan  39580.85
# 7041818  47140  39569.25  2022-08-30   39591.7   39562.2     nan  39587.65
# 7041819  47141  39547.95  2022-08-30   39570.5  39547.95     nan   39568.9
# 7041820  47142  39537.65  2022-08-30  39549.65  39529.85     nan  39548.55
# 7041821  47143  39520.35  2022-08-30  39541.75  39513.75     nan   39537.4
#
#                           symbol      time volume
# ...

# %%
main_data.drop(columns='index',inplace=True)

# %%
main_data
# Out:
#             close        date      high       low      oi      open  \
# 0          8035.6  2022-01-28    8035.6    8035.6     0.0    8035.6
# 1          7977.6  2022-01-28    7977.6    7977.6     0.0    7977.6
# 2            4.55  2022-01-28      4.55      3.05    25.0      3.05
# 3             4.0  2022-01-28      4.55      3.85  3175.0      4.55
# 4             4.0  2022-01-28       4.0      3.95  3175.0      3.95
# ...           ...         ...       ...       ...     ...       ...
# 7041817  39587.65  2022-08-30   39597.9   39579.7     nan  39580.85
# 7041818  39569.25  2022-08-30   39591.7   39562.2     nan  39587.65
# 7041819  39547.95  2022-08-30   39570.5  39547.95     nan   39568.9
# 7041820  39537.65  2022-08-30  39549.65  39529.85     nan  39548.55
# 7041821  39520.35  2022-08-30  39541.75  39513.75     nan   39537.4
#
#                           symbol      time volume
# 0        BANKNIFTY03FEB2230400CE  12:11:00     26
# ...

# %%
import pandas as pd

data1 = pd.read_csv(r'D:\speculatio\back test\stock dataset\intraday data\banknifty_raw_data_Jan18_to_27Jan22.csv')
data2 = pd.read_csv(r'D:\speculatio\back test\stock dataset\intraday data\banknifty_raw_data_28Jan22_to_aug22.csv')
data1
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9120\98891052.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1 = pd.read_csv(r'D:\speculatio\back test\stock dataset\intraday data\banknifty_raw_data_Jan18_to_27Jan22.csv')
#              close        date      high       low      oi      open  \
# 0             0.60  2018-01-01      0.60       0.6  4800.0      0.60
# 1             0.50  2018-01-01      0.50       0.5  3040.0      0.50
# 2             0.50  2018-01-01      0.50       0.5  3080.0      0.50
# 3             0.50  2018-01-01      0.50       0.5  3080.0      0.50
# 4             0.50  2018-01-01      0.50       0.5  3080.0      0.50
# ...            ...         ...       ...       ...     ...       ...
# 26648688  38069.10  2022-01-27  38070.05  38043.05     NaN  38049.80
# 26648689  38066.60  2022-01-27  38071.45   38059.4     NaN  38064.10
# 26648690  38070.10  2022-01-27  38077.75   38062.4     NaN  38066.05
# ...

# %%
data2
# Out:
#             close        date      high       low      oi      open  \
# 0         8035.60  2022-01-28   8035.60   8035.60     0.0   8035.60
# 1         7977.60  2022-01-28   7977.60   7977.60     0.0   7977.60
# 2            4.55  2022-01-28      4.55      3.05    25.0      3.05
# 3            4.00  2022-01-28      4.55      3.85  3175.0      4.55
# 4            4.00  2022-01-28      4.00      3.95  3175.0      3.95
# ...           ...         ...       ...       ...     ...       ...
# 7041817  39587.65  2022-08-30  39597.90  39579.70     NaN  39580.85
# 7041818  39569.25  2022-08-30  39591.70  39562.20     NaN  39587.65
# 7041819  39547.95  2022-08-30  39570.50  39547.95     NaN  39568.90
# 7041820  39537.65  2022-08-30  39549.65  39529.85     NaN  39548.55
# 7041821  39520.35  2022-08-30  39541.75  39513.75     NaN  39537.40
#
#                           symbol      time  volume
# 0        BANKNIFTY03FEB2230400CE  12:11:00      26
# ...

# %%
main_data = pd.concat([data1,data2])

# %%
main_data
# Out:
#             close        date      high       low      oi      open  \
# 0            0.60  2018-01-01      0.60       0.6  4800.0      0.60
# 1            0.50  2018-01-01      0.50       0.5  3040.0      0.50
# 2            0.50  2018-01-01      0.50       0.5  3080.0      0.50
# 3            0.50  2018-01-01      0.50       0.5  3080.0      0.50
# 4            0.50  2018-01-01      0.50       0.5  3080.0      0.50
# ...           ...         ...       ...       ...     ...       ...
# 7041817  39587.65  2022-08-30  39597.90   39579.7     NaN  39580.85
# 7041818  39569.25  2022-08-30  39591.70   39562.2     NaN  39587.65
# 7041819  39547.95  2022-08-30  39570.50  39547.95     NaN  39568.90
# 7041820  39537.65  2022-08-30  39549.65  39529.85     NaN  39548.55
# 7041821  39520.35  2022-08-30  39541.75  39513.75     NaN  39537.40
#
#                           symbol      time  volume
# 0        BANKNIFTY04JAN1823300PE  10:59:00    1000
# ...

# %%
spot = main_data[main_data['symbol']=='BANKNIFTY']

spot['date'] = pd.to_datetime(spot['date'])

spot.sort_values(by=['date','time'],inplace=True)
spot.reset_index(drop=True,inplace=True)

spot = spot.loc[:,['date','time','close']]
spot.rename(columns = {'close':'underlying'}, inplace=True)
spot
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9120\855481551.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spot['date'] = pd.to_datetime(spot['date'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9120\855481551.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spot.sort_values(by=['date','time'],inplace=True)
#              date      time  underlying
# 0      2018-01-01  09:00:00    25546.90
# 1      2018-01-01  09:15:00    25535.80
# 2      2018-01-01  09:16:00    25531.65
# 3      2018-01-01  09:17:00    25544.30
# ...

# %%
future = main_data[main_data['symbol']=='BANKNIFTY-I']

future['date'] = pd.to_datetime(future['date'])

future.sort_values(by=['date','time'],inplace=True)
future.reset_index(drop=True,inplace=True)

banknifty_future = future.loc[:,['date','time','close']]
banknifty_future.rename(columns = {'close':'underlying'}, inplace=True)
banknifty_future
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9120\1152188329.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   future['date'] = pd.to_datetime(future['date'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9120\1152188329.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   future.sort_values(by=['date','time'],inplace=True)
#              date      time  underlying
# 0      2018-01-01  09:15:00  25563.8000
# 1      2018-01-01  09:16:00  25569.9500
# 2      2018-01-01  09:17:00  25572.9500
# 3      2018-01-01  09:18:00  25569.0500
# ...

# %%
data = main_data[(main_data['symbol']!='BANKNIFTY') & (main_data['symbol']!='BANKNIFTY-I')]
data.reset_index(drop=True,inplace=True)

# %%
data
# Out:
#           close        date  high   low        oi  open  \
# 0          0.60  2018-01-01  0.60   0.6    4800.0  0.60
# 1          0.50  2018-01-01  0.50   0.5    3040.0  0.50
# 2          0.50  2018-01-01  0.50   0.5    3080.0  0.50
# 3          0.50  2018-01-01  0.50   0.5    3080.0  0.50
# 4          0.50  2018-01-01  0.50   0.5    3080.0  0.50
# ...         ...         ...   ...   ...       ...   ...
# 32829132   1.30  2022-08-30  1.35   1.3  638900.0  1.30
# 32829133   1.15  2022-08-30  1.35  1.15  638900.0  1.30
# 32829134   1.35  2022-08-30  1.35   1.2  632875.0  1.20
# 32829135   1.35  2022-08-30  1.40   1.3  632875.0  1.30
# 32829136   1.40  2022-08-30  1.40  1.35  632875.0  1.35
#
#                            symbol      time  volume
# 0         BANKNIFTY04JAN1823300PE  10:59:00    1000
# 1         BANKNIFTY04JAN1823400PE  09:33:00      40
# 2         BANKNIFTY04JAN1823400PE  09:36:00     360
# 3         BANKNIFTY04JAN1823400PE  09:37:00    3360
# ...

# %%
data['exp'] =  data['symbol'].apply(lambda x:x[9:16])
data['strike'] =  data['symbol'].apply(lambda x:x[16:-2])
data['option_type'] =  data['symbol'].apply(lambda x:x[-2:])
data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9120\3482696223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['exp'] =  data['symbol'].apply(lambda x:x[9:16])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9120\3482696223.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['strike'] =  data['symbol'].apply(lambda x:x[16:-2])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9120\3482696223.py:3: SettingWithCopyWarning:
# ...

# %%
data['date'] = pd.to_datetime(data['date'])
data['exp'] = pd.to_datetime(data['exp'])
data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9120\1160435250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9120\1160435250.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['exp'] = pd.to_datetime(data['exp'])
#           close       date  high   low        oi  open  \
# 0          0.60 2018-01-01  0.60   0.6    4800.0  0.60
# 1          0.50 2018-01-01  0.50   0.5    3040.0  0.50
# ...

# %%
data.sort_values(by=['date','time'],inplace=True)
data.reset_index(drop=True,inplace=True)
data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9120\902387073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.sort_values(by=['date','time'],inplace=True)
#            close       date    high    low         oi    open  \
# 0           6.10 2018-01-01    6.95   5.95    70040.0    6.50
# 1           8.30 2018-01-01    9.00   6.65   138320.0    7.00
# 2          12.75 2018-01-01   13.50   7.35   460320.0   12.50
# 3          18.80 2018-01-01   20.80   16.9   147800.0   18.55
# 4         314.20 2018-01-01  314.25  314.2    13840.0  314.25
# ...          ...        ...     ...    ...        ...     ...
# 32829132    9.70 2022-08-30    9.70    9.7   469400.0    9.70
# 32829133    6.25 2022-08-30    6.25   6.25  2395425.0    6.25
# 32829134    4.20 2022-08-30    4.20    4.2   410350.0    4.20
# ...

# %%
spot['date'] = pd.to_datetime(spot['date'])
spot
# Out:
#              date      time  underlying
# 0      2018-01-01  09:00:00    25546.90
# 1      2018-01-01  09:15:00    25535.80
# 2      2018-01-01  09:16:00    25531.65
# 3      2018-01-01  09:17:00    25544.30
# 4      2018-01-01  09:18:00    25532.55
# ...           ...       ...         ...
# 430232 2022-08-30  15:25:00    39587.65
# 430233 2022-08-30  15:26:00    39569.25
# 430234 2022-08-30  15:27:00    39547.95
# 430235 2022-08-30  15:28:00    39537.65
# 430236 2022-08-30  15:29:00    39520.35
#
# [430237 rows x 3 columns]

# %%
import pandas as pd

pd.read_csv(r'D:\speculatio\back test\stock dataset\intraday data\banknifty\banknifty_final_data.csv')
# Out:
#                 Date      Time      Expiry  Strike Price Option Type    Last  \
# 0         2018-01-01  09:15:00  2018-01-04         24800          PE    6.10
# 1         2018-01-01  09:15:00  2018-01-04         24900          PE    8.30
# 2         2018-01-01  09:15:00  2018-01-04         25000          PE   12.75
# 3         2018-01-01  09:15:00  2018-01-04         25100          PE   18.80
# 4         2018-01-01  09:15:00  2018-01-04         25200          CE  314.20
# ...              ...       ...         ...           ...         ...     ...
# 32735399  2022-08-30  15:29:00  2022-09-01         42500          CE    1.40
# 32735400  2022-08-30  15:29:00  2022-09-01         43000          CE    1.30
# 32735401  2022-08-30  15:29:00  2022-09-01         43500          CE    1.20
# 32735402  2022-08-30  15:29:00  2022-09-01         44000          CE    1.30
# 32735403  2022-08-30  15:29:00  2022-09-01         44500          CE    1.40
#
#           Underlying
# 0           25535.80
# ...

# %%
data = pd.merge(data2022,spot, on=['date','time'], how='left')
data
# Out:
#          close       date  high   low         oi  open               symbol  \
# 0         0.85 2022-04-01  0.90  0.80   325000.0  0.80  NIFTY07APR2214350PE
# 1         0.90 2022-04-01  1.30  0.90    72250.0  1.30  NIFTY07APR2214400PE
# 2         1.00 2022-04-01  1.30  0.90    78150.0  1.00  NIFTY07APR2214450PE
# 3         0.90 2022-04-01  0.95  0.85    89100.0  0.90  NIFTY07APR2214500PE
# 4         1.30 2022-04-01  1.30  1.30     1100.0  1.30  NIFTY07APR2214550PE
# ...        ...        ...   ...   ...        ...   ...                  ...
# 3720028   2.95 2022-08-30  2.95  2.95   964500.0  2.95  NIFTY01SEP2218150CE
# 3720029   2.05 2022-08-30  2.05  2.05  4670950.0  2.05  NIFTY01SEP2218200CE
# 3720030   1.80 2022-08-30  1.80  1.80   752400.0  1.80  NIFTY01SEP2218250CE
# 3720031   1.05 2022-08-30  1.05  1.05  2156950.0  1.05  NIFTY01SEP2218300CE
# 3720032   0.70 2022-08-30  0.70  0.70  1460100.0  0.70  NIFTY01SEP2218400CE
#
# ...

# %%
data = data.loc[:,['date','time','exp','strike','option_type','close','underlying']]
data.dropna(inplace=True)
data
# Out:
#               date      time        exp strike option_type  close  underlying
# 0       2022-04-01  09:15:00 2022-04-07  14350          PE   0.85    17453.95
# 1       2022-04-01  09:15:00 2022-04-07  14400          PE   0.90    17453.95
# 2       2022-04-01  09:15:00 2022-04-07  14450          PE   1.00    17453.95
# 3       2022-04-01  09:15:00 2022-04-07  14500          PE   0.90    17453.95
# 4       2022-04-01  09:15:00 2022-04-07  14550          PE   1.30    17453.95
# ...            ...       ...        ...    ...         ...    ...         ...
# 3719985 2022-08-30  15:29:00 2022-09-01  19250          CE   0.30    17744.20
# 3719986 2022-08-30  15:29:00 2022-09-01  19300          CE   0.20    17744.20
# 3719987 2022-08-30  15:29:00 2022-09-01  19350          CE   0.20    17744.20
# 3719988 2022-08-30  15:29:00 2022-09-01  19400          CE   0.25    17744.20
# 3719989 2022-08-30  15:29:00 2022-09-01  19450          CE   0.20    17744.20
#
# [3716673 rows x 7 columns]

# %%
data.rename(columns={'date':'Date','time':'Time','exp':'Expiry','option_type':'Option Type','strike':'Strike Price','close':'Last','underlying':'Underlying'},inplace=True)
data
# Out:
#               Date      Time     Expiry Strike Price Option Type  Last  \
# 0       2022-04-01  09:15:00 2022-04-07        14350          PE  0.85
# 1       2022-04-01  09:15:00 2022-04-07        14400          PE  0.90
# 2       2022-04-01  09:15:00 2022-04-07        14450          PE  1.00
# 3       2022-04-01  09:15:00 2022-04-07        14500          PE  0.90
# 4       2022-04-01  09:15:00 2022-04-07        14550          PE  1.30
# ...            ...       ...        ...          ...         ...   ...
# 3719985 2022-08-30  15:29:00 2022-09-01        19250          CE  0.30
# 3719986 2022-08-30  15:29:00 2022-09-01        19300          CE  0.20
# 3719987 2022-08-30  15:29:00 2022-09-01        19350          CE  0.20
# 3719988 2022-08-30  15:29:00 2022-09-01        19400          CE  0.25
# 3719989 2022-08-30  15:29:00 2022-09-01        19450          CE  0.20
#
#          Underlying
# 0          17453.95
# 1          17453.95
# 2          17453.95
# 3          17453.95
# ...

# %%
data.to_csv(r'D:\speculatio\back test\stock dataset\intraday data\data_Apr22_to_Aug22.csv',index=False)

# %% [markdown]
# ## merge data

# %%
final_data = pd.read_csv(r'D:\speculatio\back test\stock dataset\intraday data\final_data.csv')
final_data
# Out:
#                 Date      Time      Expiry  Strike Price Option Type     Last  \
# 0         2019-02-11  09:15:00  2019-02-14         10400          PE     2.95
# 1         2019-02-11  09:15:00  2019-02-14         10500          PE     2.10
# 2         2019-02-11  09:15:00  2019-02-14         10550          PE     3.60
# 3         2019-02-11  09:15:00  2019-02-14         10600          CE   306.95
# 4         2019-02-11  09:15:00  2019-02-14         10600          PE     7.00
# ...              ...       ...         ...           ...         ...      ...
# 17336495  2022-03-31  15:29:00  2022-03-31         18500          CE     0.05
# 17336496  2022-03-31  15:29:00  2022-03-31         18500          PE  1038.10
# 17336497  2022-03-31  15:29:00  2022-03-31         19000          PE  1535.00
# 17336498  2022-03-31  15:29:00  2022-03-31         19600          CE     0.05
# 17336499  2022-03-31  15:29:00  2022-03-31         20500          CE     0.05
#
#           Underlying
# ...

# %%
test_data = pd.concat([final_data,data])
test_data
# Out:
#                         Date      Time               Expiry Strike Price  \
# 0                 2019-02-11  09:15:00           2019-02-14        10400
# 1                 2019-02-11  09:15:00           2019-02-14        10500
# 2                 2019-02-11  09:15:00           2019-02-14        10550
# 3                 2019-02-11  09:15:00           2019-02-14        10600
# 4                 2019-02-11  09:15:00           2019-02-14        10600
# ...                      ...       ...                  ...          ...
# 3719985  2022-08-30 00:00:00  15:29:00  2022-09-01 00:00:00        19250
# 3719986  2022-08-30 00:00:00  15:29:00  2022-09-01 00:00:00        19300
# 3719987  2022-08-30 00:00:00  15:29:00  2022-09-01 00:00:00        19350
# 3719988  2022-08-30 00:00:00  15:29:00  2022-09-01 00:00:00        19400
# 3719989  2022-08-30 00:00:00  15:29:00  2022-09-01 00:00:00        19450
#
#         Option Type    Last  Underlying
# 0                PE    2.95    10897.85
# ...

# %%
test_data['Date'] = pd.to_datetime(test_data['Date'])
test_data
# Out:
#               Date      Time               Expiry Strike Price Option Type  \
# 0       2019-02-11  09:15:00           2019-02-14        10400          PE
# 1       2019-02-11  09:15:00           2019-02-14        10500          PE
# 2       2019-02-11  09:15:00           2019-02-14        10550          PE
# 3       2019-02-11  09:15:00           2019-02-14        10600          CE
# 4       2019-02-11  09:15:00           2019-02-14        10600          PE
# ...            ...       ...                  ...          ...         ...
# 3719985 2022-08-30  15:29:00  2022-09-01 00:00:00        19250          CE
# 3719986 2022-08-30  15:29:00  2022-09-01 00:00:00        19300          CE
# 3719987 2022-08-30  15:29:00  2022-09-01 00:00:00        19350          CE
# 3719988 2022-08-30  15:29:00  2022-09-01 00:00:00        19400          CE
# 3719989 2022-08-30  15:29:00  2022-09-01 00:00:00        19450          CE
#
#            Last  Underlying
# 0          2.95    10897.85
# ...

# %%
test_data.to_csv(r'D:\speculatio\back test\stock dataset\intraday data\data_Jan19_to_Aug22.csv',index=False)

# %%
data19 = pd.read_csv(r'D:\speculatio\back test\stock dataset\intraday data\data2019.csv')
data20 = pd.read_csv(r'D:\speculatio\back test\stock dataset\intraday data\data2020.csv')
data21 = pd.read_csv(r'D:\speculatio\back test\stock dataset\intraday data\data2021.csv')
data22 = pd.read_csv(r'D:\speculatio\back test\stock dataset\intraday data\data2022.csv')

# %%
main_data = pd.concat([data19,data20,data21,data22])
main_data
# Out:
#          Unnamed: 0        date      time         exp  strike option_type  \
# 0                 0  2019-02-11  09:15:00  2019-02-14   10400          PE
# 1                 1  2019-02-11  09:15:00  2019-02-14   10500          PE
# 2                 2  2019-02-11  09:15:00  2019-02-14   10550          PE
# 3                 3  2019-02-11  09:15:00  2019-02-14   10600          CE
# 4                 4  2019-02-11  09:15:00  2019-02-14   10600          PE
# ...             ...         ...       ...         ...     ...         ...
# 2344720     2347088  2022-03-31  15:29:00  2022-03-31   18500          CE
# 2344721     2347089  2022-03-31  15:29:00  2022-03-31   18500          PE
# 2344722     2347090  2022-03-31  15:29:00  2022-03-31   19000          PE
# 2344723     2347091  2022-03-31  15:29:00  2022-03-31   19600          CE
# 2344724     2347092  2022-03-31  15:29:00  2022-03-31   20500          CE
#
#            close  underlying
# 0           2.95    10897.85
# ...

# %%
main_data.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
main_data.sort_values(by=['date','time'],inplace=True)

# %%
main_data.reset_index(drop=True,inplace=True)
main_data
# Out:
#                 date      time         exp  strike option_type    close  \
# 0         2019-02-11  09:15:00  2019-02-14   10400          PE     2.95
# 1         2019-02-11  09:15:00  2019-02-14   10500          PE     2.10
# 2         2019-02-11  09:15:00  2019-02-14   10550          PE     3.60
# 3         2019-02-11  09:15:00  2019-02-14   10600          CE   306.95
# 4         2019-02-11  09:15:00  2019-02-14   10600          PE     7.00
# ...              ...       ...         ...     ...         ...      ...
# 17336495  2022-03-31  15:29:00  2022-03-31   18500          CE     0.05
# 17336496  2022-03-31  15:29:00  2022-03-31   18500          PE  1038.10
# 17336497  2022-03-31  15:29:00  2022-03-31   19000          PE  1535.00
# 17336498  2022-03-31  15:29:00  2022-03-31   19600          CE     0.05
# 17336499  2022-03-31  15:29:00  2022-03-31   20500          CE     0.05
#
#           underlying
# 0           10897.85
# 1           10897.85
# 2           10897.85
# ...

# %%
main_data.rename(columns={'date':'Date','time':'Time','exp':'Expiry','option_type':'Option Type','strike':'Strike Price','close':'Last','underlying':'Underlying'},inplace=True)

# %%
main_data.to_csv(r'D:\speculatio\back test\stock dataset\intraday data\final_data.csv',index=False)
