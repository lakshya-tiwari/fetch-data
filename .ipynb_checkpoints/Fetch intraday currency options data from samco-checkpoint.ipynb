# %% [markdown]
# ### fetch intraday currency options data

# %%
from snapi_py_client.snapi_bridge import StocknoteAPIPythonBridge
import json 

import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta, time
import time as Time


while datetime.now().time() < time(17, 5, 30):
    Time.sleep(1)

samco=StocknoteAPIPythonBridge()
login=json.loads(samco.login(body={"userId":'DL31725','password':'Bharat@9998','yob':'1998'}))
samco.set_session_token(sessionToken=login['sessionToken'])


currency_list = ['EURINR','GBPINR','JPYINR','USDINR']


for currency in currency_list:

    option_chain = pd.DataFrame(json.loads(samco.get_option_chain(search_symbol_name=currency,exchange=samco.EXCHANGE_CDS))['optionChainDetails'])

    symbols = option_chain[option_chain['lastTradedPrice']!='0.0000']['tradingSymbol'].unique()

    main_data = pd.DataFrame()

    start_date = str(date.today())+' 09:00:00'
    end_date = str(date.today())+' 17:00:00'

    for i in symbols:
        print(i)

        try:
            data = pd.DataFrame(json.loads(samco.get_intraday_candle_data(symbol_name=i,exchange=samco.EXCHANGE_CDS, from_date=start_date, to_date=end_date))['intradayCandleData'])
            data['symbol']=i   #'NIFTY05JAN2318300CE'
            main_data = pd.concat([main_data,data],axis=0)
        except:
            continue


    main_data['dateTime'] = pd.to_datetime(main_data['dateTime'])
    main_data.sort_values(by='dateTime',inplace=True)

    path = fr'E:/option_data/CURRENCY/{currency}/2024/JAN/data_'
    dates = path+str(date.today())+'.csv'

    main_data.to_csv(dates,index=False)
    
samco.logout()
# Out:
# EURINR2411994CE
# EURINR24JAN93.5CE
# EURINR2410593PE
# EURINR24JAN93CE
# EURINR24JAN93PE
# EURINR24JAN92.5PE
# EURINR24FEB92.5CE
# EURINR24JAN92CE
# EURINR24JAN92PE
# EURINR2411292CE
# EURINR24JAN91.5PE
# EURINR24JAN91CE
# EURINR24JAN91PE
# EURINR24JAN90PE
# EURINR24MAR89.5PE
# EURINR24JAN89PE
# EURINR24JAN88CE
# EURINR24MAR86.25PE
# GBPINR24JAN109CE
# GBPINR24JAN108.5CE
# GBPINR24112108CE
# GBPINR24JAN108CE
# GBPINR24JAN108PE
# GBPINR24125108CE
# GBPINR24JAN107.75CE
# GBPINR24JAN107.75PE
# GBPINR24JAN107.5CE
# GBPINR24JAN107.5PE
# GBPINR24JAN107.25CE
# GBPINR24JAN107.25PE
# GBPINR24JAN107CE
# GBPINR24JAN107PE
# GBPINR24JAN106.75CE
# GBPINR24JAN106.75PE
# GBPINR24JAN106.5CE
# GBPINR24JAN106.5PE
# GBPINR24JAN106.25CE
# GBPINR24JAN106.25PE
# GBPINR24105106PE
# GBPINR24JAN106CE
# GBPINR24JAN106PE
# GBPINR24JAN105.75CE
# GBPINR24JAN105.75PE
# GBPINR24JAN105.5CE
# GBPINR24JAN105.5PE
# GBPINR24JAN105.25CE
# GBPINR24JAN105.25PE
# GBPINR24105105CE
# GBPINR24105105PE
# GBPINR24JAN105CE
# GBPINR24JAN105PE
# GBPINR24125105PE
# GBPINR24JAN104.75PE
# GBPINR24JAN104.5CE
# GBPINR24JAN104.5PE
# GBPINR24JAN104.25CE
# USDINR2420981.75PE
# USDINR24FEB81.75PE
# USDINR2410581.5CE
# USDINR2410581.5PE
# USDINR2411981.5CE
# USDINR2421681.5PE
# USDINR2430181.5PE
# USDINR2412581.5CE
# USDINR2420281.5PE
# USDINR2411281.5CE
# USDINR24MAR81.5PE
# USDINR24JAN81.5CE
# USDINR24JAN81.5PE
# USDINR2420981.5PE
# USDINR24FEB81.5PE
# USDINR2410581.25CE
# USDINR2410581.25PE
# USDINR2411981.25CE
# USDINR2430181.25PE
# USDINR2412581.25CE
# USDINR2411281.25CE
# USDINR24MAR81.25PE
# USDINR24JAN81.25CE
# USDINR24JAN81.25PE
# USDINR24FEB81.25PE
# USDINR2410581CE
# USDINR2410581PE
# USDINR2411981CE
# USDINR2430181PE
# USDINR2412581CE
# USDINR2412581PE
# USDINR2411281CE
# USDINR24MAR81PE
# USDINR24JAN81CE
# USDINR24JAN81PE
# USDINR24FEB81CE
# USDINR24FEB81PE
# USDINR2410580.75CE
# USDINR2410580.75PE
# USDINR2411980.75CE
# USDINR2411980.75PE
# USDINR2412580.75CE
# USDINR2411280.75CE
# USDINR24JAN80.75CE
# USDINR24JAN80.75PE
# USDINR24FEB80.75PE
# USDINR2410580.5CE
# USDINR2410580.5PE
# USDINR2411980.5CE
# USDINR2412580.5CE
# USDINR2411280.5CE
# USDINR24JAN80.5CE
# USDINR24JAN80.5PE
# USDINR24FEB80.5PE
# USDINR2410580.25CE
# USDINR2410580.25PE
# USDINR2411980.25CE
# USDINR2412580.25CE
# USDINR2411280.25CE
# USDINR24JAN80.25CE
# USDINR24JAN80.25PE
# USDINR24FEB80.25PE
# USDINR2410580CE
# USDINR2410580PE
# USDINR2411980CE
# USDINR2412580CE
# USDINR2412580PE
# USDINR2411280CE
# USDINR24MAR80PE
# USDINR24JAN80CE
# USDINR24JAN80PE
# USDINR24FEB80PE
# USDINR24MAR79.75PE
# USDINR24MAR78.5PE
# USDINR24MAR78PE
# USDINR24MAR77PE
# '{\n  "serverTime": "01/01/24 17:05:54",\n  "msgId": "e5b0c5c5-b903-464a-9d9a-2620fb721e83",\n  "status": "Success",\n  "statusMessage": "User has successfully logged out"\n}'

# %%
import os
os.system("shutdown /s /t 1")

# %% [markdown]
# #### Move file one folder to another

# %%
import shutil

currency_list = ['EURINR','GBPINR','JPYINR','USDINR']
dates = ['2024-01-01']

for currency in currency_list:
    path = fr'E:\option_data\CURRENCY\{currency}\2023\DEC\data_'
    
    for D in dates:
        source_path = path+str(D)+'.csv'

        destination_path = fr'E:/option_data/CURRENCY/{currency}/2024/DEC/'

        # Use shutil.move to move the file
        shutil.move(source_path, destination_path)

# %% [markdown]
# ### fetch intraday MCX options data

# %%
from snapi_py_client.snapi_bridge import StocknoteAPIPythonBridge
import json 

import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta, time
import time as Time
import pytz

samco=StocknoteAPIPythonBridge()
login=json.loads(samco.login(body={"userId":'DA47853','password':'Bharat@11','yob':'1984'}))
samco.set_session_token(sessionToken=login['sessionToken'])


MCX_list = ['GOLD','SILVER','CRUDEOIL','NICKEL','COPPER','NATURALGAS','ZINC']


for metal in MCX_list:

    option_chain = pd.DataFrame(json.loads(samco.get_option_chain(search_symbol_name=metal,exchange=samco.EXCHANGE_MCX))['optionChainDetails'])

    symbols = option_chain[option_chain['lastTradedPrice']!='0.00']['tradingSymbol'].unique()
    
    if len(symbols)==0:
        continue
    
    main_data = pd.DataFrame()
    
    day = date.today()
    start_date = str(day)+' 09:00:00'
    end_date = str(day)+' 23:30:00'

    for i in symbols:
        print(i)

        try:
            data = pd.DataFrame(json.loads(samco.get_intraday_candle_data(symbol_name=i,exchange=samco.EXCHANGE_MCX, from_date=start_date, to_date=end_date))['intradayCandleData'])
            data['symbol']=i   #'NIFTY05JAN2318300CE'
            main_data = pd.concat([main_data,data],axis=0)
        except:
            continue


    main_data['dateTime'] = pd.to_datetime(main_data['dateTime'])
    main_data.sort_values(by=['dateTime'],inplace=True)

    path = f'E:\option_data\MCX\{metal}\data_'
    dates = path+str(date.today())+'.csv'

#     main_data.to_csv(dates,index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [2], in <cell line: 12>()
#      10 samco=StocknoteAPIPythonBridge()
#      11 login=json.loads(samco.login(body={"userId":'DA47853','password':'Bharat@11','yob':'1984'}))
# ---> 12 samco.set_session_token(sessionToken=login['sessionToken'])
#      15 MCX_list = ['GOLD','SILVER','CRUDEOIL','NICKEL','COPPER','NATURALGAS','ZINC']
#      18 for metal in MCX_list:
#
# KeyError: 'sessionToken'

# %%
import pandas as pd
import os

path = 'D:\speculatio\EMA Samco_Tradesheet'
broker_account_path = r'D:\speculatio\EMA Samco_Tradesheet\account_details\Account_Details.csv'
accountdetails = pd.read_csv(broker_account_path)

files =  [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
final_data = pd.DataFrame()

for F in files:
    
    user_name = F.split('_trade')[0]
    trade_df = pd.read_csv(f"{path}\{F}",header=None)
    if trade_df.iloc[-1,2]=='BUY':
        trade_df = trade_df[:-1]

    user_account_detail = accountdetails[accountdetails['user_name']==user_name]
    initial_capital = user_account_detail['initial_capital'].iloc[0]
    # start_date = user_account_detail['start_date'].iloc[0]

    df = pd.DataFrame(columns=range(12))

    j=0

    for i in range(0,len(trade_df),2):

        df.at[j] = trade_df.iloc[i]

        try:
            if (trade_df.iloc[i,[4,5]] == trade_df.iloc[(i+1),[4,5]]).all() and (trade_df.iloc[i,2]=='BUY') and (trade_df.iloc[(i+1),2]=='SELL'):

                df.at[j,6] = trade_df.iloc[(i+1),3]
                df.at[j,7] = (df.iloc[j,6] - df.iloc[j,3])
                df.at[j,8] =  (df.at[j,7])* int(df.iloc[j,5])
                df.at[j,9] = round(df.iloc[j,7]/df.iloc[j,3]*100,2)
                df.at[j,10] = (3.4*df.iloc[j,5])+40
                df.at[j,11] = round((df.iloc[j,7]-(df.at[j,10]/int(df.iloc[j,5])))/df.iloc[j,3]*100,2)
                df.at[j,12] = initial_capital + sum(df[8]) - sum(df[10])

                j+=1

        except IndexError:
            pass


    df.rename(columns={0:'Date Time',1:'Symbol',2:'Trade Type',3:'Buy Price',4:'Status',5:'Qty',6:'Sell Price',7:'PnL',8:'Total PnL',9:'Gross PnL %',10:'Expenses',11:'Net PnL %',12:'Final capital'},inplace=True)
    df.fillna(0,inplace=True)
    
    df['user'] = user_name
    df['result'] = df['Net PnL %'].apply(lambda x: 'win' if x>0 else 'loss')

    for i in range(len(df)):
        df.at[i, 'DD'] = round((df.loc[i, 'Final capital'] / pd.concat([df.loc[:i, 'Final capital'], pd.Series(initial_capital)]).max() - 1) * 100,2)

    df.dropna(inplace=True)
    df['Trade_no'] = df.index
    
    final_data = pd.concat([final_data,df])

# %%
final_data
# Out:
#                Date Time         Symbol Trade Type  Buy Price    Status   Qty  \
# 0   01-Jun-2023 10:30:00  NIFTY23JUNFUT        BUY   18634.40  Complete  50.0
# 1   02-Jun-2023 09:29:59  NIFTY23JUNFUT        BUY   18640.00  Complete  50.0
# 2   02-Jun-2023 13:30:00  NIFTY23JUNFUT        BUY   18662.90  Complete  50.0
# 3   05-Jun-2023 09:30:05  NIFTY23JUNFUT        BUY   18704.90  Complete  50.0
# 4   07-Jun-2023 09:15:04  NIFTY23JUNFUT        BUY   18712.10  Complete  50.0
# ..                   ...            ...        ...        ...       ...   ...
# 49  21-Nov-2023 09:30:01  NIFTY23NOVFUT        BUY   19833.00  Complete  50.0
# 50  22-Nov-2023 14:30:00  NIFTY23NOVFUT        BUY   19848.00  Complete  50.0
# 51  24-Nov-2023 11:30:01  NIFTY23NOVFUT        BUY   19856.40  Complete  50.0
# 52  24-Nov-2023 14:30:00  NIFTY23NOVFUT        BUY   19836.50  Complete  50.0
# 53  28-Nov-2023 09:30:03  NIFTY23NOVFUT        BUY   19855.95  Complete  50.0
#
#     Sell Price     PnL  Total PnL  Gross PnL %  Expenses  Net PnL %  \
# 0     18602.30  -32.10    -1605.0        -0.17     210.0      -0.19
# 1     18571.10  -68.90    -3445.0        -0.37     210.0      -0.39
# 2     18610.00  -52.90    -2645.0        -0.28     210.0      -0.31
# 3     18641.60  -63.30    -3165.0        -0.34     210.0      -0.36
# 4     18724.05   11.95      597.5         0.06     210.0       0.04
# ..         ...     ...        ...          ...       ...        ...
# 49    19765.85  -67.15    -3357.5        -0.34     210.0      -0.36
# 50    19821.90  -26.10    -1305.0        -0.13     210.0      -0.15
# 51    19827.40  -29.00    -1450.0        -0.15     210.0      -0.17
# 52    19852.80   16.30      815.0         0.08     210.0       0.06
# 53    20081.20  225.25    11262.5         1.13     210.0       1.11
#
#     Final capital          user result    DD  Trade_no
# 0        998185.0  Akshat_Mamta   loss -0.18         0
# 1        994530.0  Akshat_Mamta   loss -0.55         1
# 2        991675.0  Akshat_Mamta   loss -0.83         2
# 3        988300.0  Akshat_Mamta   loss -1.17         3
# 4        988687.5  Akshat_Mamta    win -1.13         4
# ..            ...           ...    ...   ...       ...
# 49       518320.0        Rajesh   loss -1.70        49
# 50       516805.0        Rajesh   loss -1.99        50
# 51       515145.0        Rajesh   loss -2.31        51
# 52       515750.0        Rajesh    win -2.19        52
# 53       526802.5        Rajesh    win -0.09        53
#
# [495 rows x 17 columns]
